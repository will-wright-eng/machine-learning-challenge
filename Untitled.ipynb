# %%
ls
# Out:
# Images/                              machine_learning_grading_rubric.pdf
# README.md                            starter_code/
# Untitled.ipynb

# %%
import os

cwd = os.getcwd()
print(cwd)
# os.chdir(cwd+'')
# Out:
# /Users/williamwright/Documents/berkeley_boot_camp/Homework/machine-learning-challenge

# %%
os.chdir(cwd+'/starter_code')

# %%
ls
# Out:
# exoplanet_data.csv  model_1.ipynb

# %%
import pandas as pd
df = pd.read_csv('exoplanet_data.csv')
os.chdir(cwd)
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
pd.set_option("display.max_rows", 200)
pd.set_option("display.max_columns", 200)
# df

# %%
list(df)
# Out:
# ['koi_disposition',
#  'koi_fpflag_nt',
#  'koi_fpflag_ss',
#  'koi_fpflag_co',
#  'koi_fpflag_ec',
#  'koi_period',
#  'koi_period_err1',
#  'koi_period_err2',
#  'koi_time0bk',
#  'koi_time0bk_err1',
#  'koi_time0bk_err2',
#  'koi_impact',
#  'koi_impact_err1',
#  'koi_impact_err2',
#  'koi_duration',
#  'koi_duration_err1',
#  'koi_duration_err2',
#  'koi_depth',
#  'koi_depth_err1',
#  'koi_depth_err2',
#  'koi_prad',
#  'koi_prad_err1',
#  'koi_prad_err2',
#  'koi_teq',
#  'koi_insol',
#  'koi_insol_err1',
#  'koi_insol_err2',
#  'koi_model_snr',
#  'koi_tce_plnt_num',
#  'koi_steff',
#  'koi_steff_err1',
#  'koi_steff_err2',
#  'koi_slogg',
#  'koi_slogg_err1',
#  'koi_slogg_err2',
#  'koi_srad',
#  'koi_srad_err1',
#  'koi_srad_err2',
#  'ra',
#  'dec',
#  'koi_kepmag']

# %%
cols = ['rowid'
, 'kepid'
, 'kepoi_name'
, 'kepler_name'
, 'koi_disposition'
, 'koi_pdisposition'
, 'koi_score'
, 'koi_fpflag_nt'
, 'koi_fpflag_ss'
, 'koi_fpflag_co'
, 'koi_fpflag_ec'
, 'koi_period'
, 'koi_period_err1'
, 'koi_period_err2'
, 'koi_time0bk'
, 'koi_time0bk_err1'
, 'koi_time0bk_err2'
, 'koi_impact'
, 'koi_impact_err1'
, 'koi_impact_err2'
, 'koi_duration'
, 'koi_duration_err1'
, 'koi_duration_err2'
, 'koi_depth'
, 'koi_depth_err1'
, 'koi_depth_err2'
, 'koi_prad'
, 'koi_prad_err1'
, 'koi_prad_err2'
, 'koi_teq'
, 'koi_teq_err1'
, 'koi_teq_err2'
, 'koi_insol'
, 'koi_insol_err1'
, 'koi_insol_err2'
, 'koi_model_snr'
, 'koi_tce_plnt_num'
, 'koi_tce_delivname'
, 'koi_steff'
, 'koi_steff_err1'
, 'koi_steff_err2'
, 'koi_slogg'
, 'koi_slogg_err1'
, 'koi_slogg_err2'
, 'koi_srad'
, 'koi_srad_err1'
, 'koi_srad_err2'
, 'ra'
, 'dec'
, 'koi_kepmag']

cols0 = list(df)


# list_1 = [1, 2, 3, 4, 5, 6]
# list_2 = [1, 2, 3, 0, 5, 6]

list_1 = cols
list_2 = cols0

# Print all items from list_1 that are not in list_2 ()
# print(*[item for item in list_1 if item not in list_2], sep='\n')

# Print all items from list_1 that differ from the item at the same index in list_2
print(*[x for x, y in zip(list_1, list_2) if x != y], sep='\n')

# Print all items from list_2 that differ from the item at the same index in list_1
# print(*[y for x, y in zip(list_1, list_2) if x != y], sep='\n')
# Out:
# rowid
# kepid
# kepoi_name
# kepler_name
# koi_disposition
# koi_pdisposition
# koi_score
# koi_fpflag_nt
# koi_fpflag_ss
# koi_fpflag_co
# koi_fpflag_ec
# koi_period
# koi_period_err1
# koi_period_err2
# koi_time0bk
# koi_time0bk_err1
# koi_time0bk_err2
# koi_impact
# koi_impact_err1
# koi_impact_err2
# koi_duration
# koi_duration_err1
# koi_duration_err2
# koi_depth
# koi_depth_err1
# koi_depth_err2
# koi_prad
# koi_prad_err1
# koi_prad_err2
# koi_teq
# koi_teq_err1
# koi_teq_err2
# koi_insol
# koi_insol_err1
# koi_insol_err2
# koi_model_snr
# koi_tce_plnt_num
# koi_tce_delivname
# koi_steff
# koi_steff_err1
# koi_steff_err2

# %%
ls
# Out:
# Images/                              kepler-exoplanet-search-results.zip
# README.md                            machine_learning_grading_rubric.pdf
# Untitled.ipynb                       starter_code/
# cumulative.csv*

# %%
df = pd.read_csv('cumulative.csv')
df
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# 1           CANDIDATE      0.969              0              0              0
# 2      FALSE POSITIVE      0.000              0              1              0
# 3      FALSE POSITIVE      0.000              0              1              0
# 4           CANDIDATE      1.000              0              0              0
# ...               ...        ...            ...            ...            ...
# 9559   FALSE POSITIVE      0.000              0              0              0
# 9560   FALSE POSITIVE      0.000              0              1              1
# 9561        CANDIDATE      0.497              0              0              0
# 9562   FALSE POSITIVE      0.021              0              0              1
# 9563   FALSE POSITIVE      0.000              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0    9.488036     2.775000e-05    -2.775000e-05
# 1                 0   54.418383     2.479000e-04    -2.479000e-04
# 2                 0   19.899140     1.494000e-05    -1.494000e-05
# 3                 0    1.736952     2.630000e-07    -2.630000e-07
# 4                 0    2.525592     3.761000e-06    -3.761000e-06
# ...             ...         ...              ...              ...
# 9559              1    8.589871     1.846000e-04    -1.846000e-04
# 9560              0    0.527699     1.160000e-07    -1.160000e-07
# 9561              0    1.739849     1.780000e-05    -1.780000e-05
# 9562              0    0.681402     2.434000e-06    -2.434000e-06
# 9563              1    4.856035     6.356000e-05    -6.356000e-05
#
#       koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  koi_impact  \
# 0      170.538750          0.002160         -0.002160       0.146
# 1      162.513840          0.003520         -0.003520       0.586
# 2      175.850252          0.000581         -0.000581       0.969
# 3      170.307565          0.000115         -0.000115       1.276
# 4      171.595550          0.001130         -0.001130       0.701
# ...           ...               ...               ...         ...
# 9559   132.016100          0.015700         -0.015700       0.765
# 9560   131.705093          0.000170         -0.000170       1.252
# 9561   133.001270          0.007690         -0.007690       0.043
# 9562   132.181750          0.002850         -0.002850       0.147
# 9563   135.993300          0.010800         -0.010800       0.134
#
#       koi_impact_err1  koi_impact_err2  koi_duration  koi_duration_err1  \
# 0               0.318           -0.146       2.95750            0.08190
# 1               0.059           -0.443       4.50700            0.11600
# 2               5.126           -0.077       1.78220            0.03410
# 3               0.115           -0.092       2.40641            0.00537
# 4               0.235           -0.478       1.65450            0.04200
# ...               ...              ...           ...                ...
# 9559            0.023           -0.541       4.80600            0.63400
# 9560            0.051           -0.049       3.22210            0.01740
# 9561            0.423           -0.043       3.11400            0.22900
# 9562            0.309           -0.147       0.86500            0.16200
# 9563            0.323           -0.134       3.07800            0.28300
#
#       koi_duration_err2  koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  \
# 0              -0.08190      615.8            19.5           -19.5      2.26
# 1              -0.11600      874.8            35.5           -35.5      2.83
# 2              -0.03410    10829.0           171.0          -171.0     14.60
# 3              -0.00537     8079.2            12.8           -12.8     33.46
# 4              -0.04200      603.3            16.9           -16.9      2.75
# ...                 ...        ...             ...             ...       ...
# 9559           -0.63400       87.7            13.0           -13.0      1.11
# 9560           -0.01740     1579.2             4.6            -4.6     29.35
# 9561           -0.22900       48.5             5.4            -5.4      0.72
# 9562           -0.16200      103.6            14.7           -14.7      1.07
# 9563           -0.28300       76.7            10.8           -10.8      1.05
#
#       koi_prad_err1  koi_prad_err2  koi_teq  koi_teq_err1  koi_teq_err2  \
# 0              0.26          -0.15    793.0           NaN           NaN
# 1              0.32          -0.19    443.0           NaN           NaN
# 2              3.92          -1.31    638.0           NaN           NaN
# 3              8.50          -2.83   1395.0           NaN           NaN
# 4              0.88          -0.35   1406.0           NaN           NaN
# ...             ...            ...      ...           ...           ...
# 9559           0.32          -0.23    929.0           NaN           NaN
# 9560           7.70          -2.57   2088.0           NaN           NaN
# 9561           0.24          -0.08   1608.0           NaN           NaN
# 9562           0.36          -0.11   2218.0           NaN           NaN
# 9563           0.36          -0.12   1266.0           NaN           NaN
#
#       koi_insol  koi_insol_err1  koi_insol_err2  koi_model_snr  \
# 0         93.59           29.45          -16.65           35.8
# 1          9.11            2.87           -1.62           25.8
# 2         39.30           31.04          -10.49           76.3
# 3        891.96          668.95         -230.35          505.6
# 4        926.16          874.33         -314.24           40.9
# ...         ...             ...             ...            ...
# 9559     176.40          152.77          -77.60            8.4
# 9560    4500.53         3406.38        -1175.26          453.3
# 9561    1585.81         1537.86         -502.22           10.6
# 9562    5713.41         5675.74        -1836.94           12.3
# 9563     607.42          600.39         -194.33            8.2
#
#       koi_tce_plnt_num koi_tce_delivname  koi_steff  koi_steff_err1  \
# 0                  1.0   q1_q17_dr25_tce     5455.0            81.0
# 1                  2.0   q1_q17_dr25_tce     5455.0            81.0
# 2                  1.0   q1_q17_dr25_tce     5853.0           158.0
# 3                  1.0   q1_q17_dr25_tce     5805.0           157.0
# 4                  1.0   q1_q17_dr25_tce     6031.0           169.0
# ...                ...               ...        ...             ...
# 9559               1.0   q1_q17_dr25_tce     5638.0           169.0
# 9560               1.0   q1_q17_dr25_tce     5638.0           139.0
# 9561               1.0   q1_q17_dr25_tce     6119.0           165.0
# 9562               1.0   q1_q17_dr25_tce     6173.0           193.0
# 9563               1.0   q1_q17_dr25_tce     6469.0           158.0
#
#       koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0              -81.0      4.467           0.064          -0.096     0.927
# 1              -81.0      4.467           0.064          -0.096     0.927
# 2             -176.0      4.544           0.044          -0.176     0.868
# 3             -174.0      4.564           0.053          -0.168     0.791
# 4             -211.0      4.438           0.070          -0.210     1.046
# ...              ...        ...             ...             ...       ...
# 9559          -152.0      4.296           0.231          -0.189     1.088
# 9560          -166.0      4.529           0.035          -0.196     0.903
# 9561          -220.0      4.444           0.056          -0.224     1.031
# 9562          -236.0      4.447           0.056          -0.224     1.041
# 9563          -225.0      4.385           0.054          -0.216     1.193
#
#       koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0             0.105         -0.061  291.93423  48.141651      15.347
# 1             0.105         -0.061  291.93423  48.141651      15.347
# 2             0.233         -0.078  297.00482  48.134129      15.436
# 3             0.201         -0.067  285.53461  48.285210      15.597
# 4             0.334         -0.133  288.75488  48.226200      15.509
# ...             ...            ...        ...        ...         ...
# 9559          0.313         -0.228  298.74921  46.973351      14.478
# 9560          0.237         -0.079  297.18875  47.093819      14.082
# 9561          0.341         -0.114  286.50937  47.163219      14.757
# 9562          0.341         -0.114  294.16489  47.176281      15.385
# 9563          0.410         -0.137  297.00977  47.121021      14.826
#
# [9564 rows x 50 columns]

# %%
# https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html

list(df)

col_mapping = {
    # stellar parameters
    'koi_steff' : 'stellar effective temperature (Kelvin)'
    , 'koi_slogg' : 'stellar surface gravity (base-10 logarithm)'
    , 'koi_srad' : 'stellar radius (solar radii)'
    # exoplanet archive information
    , 'koi_disposition' : 'exoplanet archive disposition'
    , 'kepoi_name' : 'kepler object of interest -- name'
    # identification columns
    , 'kepid' : 'target identification number'
    # transit properties
    , 'koi_period' : 'orbital period (days)'
    , 'koi_prad' : 'planetary radius (earth radii)'
    , 'koi_teq' : 'equilibrium temperature (kelvin)'

}

df[list(col_mapping)]
# Out:
#       koi_steff  koi_slogg  koi_srad koi_disposition kepoi_name     kepid  \
# 0        5455.0      4.467     0.927       CONFIRMED  K00752.01  10797460
# 1        5455.0      4.467     0.927       CONFIRMED  K00752.02  10797460
# 2        5853.0      4.544     0.868  FALSE POSITIVE  K00753.01  10811496
# 3        5805.0      4.564     0.791  FALSE POSITIVE  K00754.01  10848459
# 4        6031.0      4.438     1.046       CONFIRMED  K00755.01  10854555
# ...         ...        ...       ...             ...        ...       ...
# 9559     5638.0      4.296     1.088  FALSE POSITIVE  K07984.01  10031643
# 9560     5638.0      4.529     0.903  FALSE POSITIVE  K07985.01  10090151
# 9561     6119.0      4.444     1.031       CANDIDATE  K07986.01  10128825
# 9562     6173.0      4.447     1.041  FALSE POSITIVE  K07987.01  10147276
# 9563     6469.0      4.385     1.193  FALSE POSITIVE  K07989.01  10156110
#
#       koi_period  koi_prad  koi_teq
# 0       9.488036      2.26    793.0
# 1      54.418383      2.83    443.0
# 2      19.899140     14.60    638.0
# 3       1.736952     33.46   1395.0
# 4       2.525592      2.75   1406.0
# ...          ...       ...      ...
# 9559    8.589871      1.11    929.0
# 9560    0.527699     29.35   2088.0
# 9561    1.739849      0.72   1608.0
# 9562    0.681402      1.07   2218.0
# 9563    4.856035      1.05   1266.0
#
# [9564 rows x 9 columns]
